# %% [markdown]
# <a href="https://colab.research.google.com/github/immune-institute/viz-geospatial-exercise-1-todo/blob/main/VIZ_Geospatial_Exercise_1_TODO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**CLASS EXERCISES**

# %% [markdown]
# ##**Initial Setup**

# %%
# !pip install --upgrade plotly

# %% [markdown]
# ###**EXERCISE 1**: *

# %% [markdown]
# Import plotly express and pandas:

# %%
#CODE HERE

# %%
# Out:
# '4.8.2'

# %% [markdown]
# ##**Scatter**

# %% [markdown]
# ###**EXERCISE 2**: *

# %% [markdown]
# Create the following map with provided dataset:

# %%
#DATA
us_cities_data = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv")

# %%
#CODE HERE

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f183f755-1313-453c-a3e5-9a2d7ebc92d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f183f755-1313-453c-a3e5-9a2d7ebc92d3")) {
#                     Plotly.newPlot(
#                         'f183f755-1313-453c-a3e5-9a2d7ebc92d3',
# ...

# %% [markdown]
# ###**EXERCISE 3**: *

# %% [markdown]
# Create the following map with provided dataset:

# %%
#DATA
us_cities_data = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv")

# %%
#CODE HERE

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="057a6c14-6624-47c5-9b5f-baa036d161fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("057a6c14-6624-47c5-9b5f-baa036d161fc")) {
#                     Plotly.newPlot(
#                         '057a6c14-6624-47c5-9b5f-baa036d161fc',
# ...

# %% [markdown]
# ###**EXERCISE 4**: *

# %% [markdown]
# Create the following map with provided dataset:

# %%
#DATA
airport_traffic_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')

# %%
#CODE HERE

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6af90cdf-079b-48bb-a9ff-8c1ddc89eeef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6af90cdf-079b-48bb-a9ff-8c1ddc89eeef")) {
#                     Plotly.newPlot(
#                         '6af90cdf-079b-48bb-a9ff-8c1ddc89eeef',
# ...

# %% [markdown]
# ##**Choropleth**

# %% [markdown]
# ###**EXERCISE 5**: **

# %% [markdown]
# Create the following map with provided dataset:

# %%
#DATA
from urllib.request import urlopen
import json

#GeoJson Districts
election_data_geojson = px.data.election_geojson()

#Election Dataset
election_data = px.data.election()

# %%
#CODE HERE

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b36c6114-5459-4b5e-80bc-462d5d40a404" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b36c6114-5459-4b5e-80bc-462d5d40a404")) {
#                     Plotly.newPlot(
#                         'b36c6114-5459-4b5e-80bc-462d5d40a404',
# ...

# %%
#CODE HERE

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f1ecb706-e786-4234-9e18-a1973c879e4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1ecb706-e786-4234-9e18-a1973c879e4e")) {
#                     Plotly.newPlot(
#                         'f1ecb706-e786-4234-9e18-a1973c879e4e',
# ...

# %% [markdown]
# ###**EXERCISE 6**: *

# %% [markdown]
# Create the following map with provided dataset:

# %%
#DATA
gap_data = px.data.gapminder()

# %%
#CODE HERE

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="80e4ae3a-cadc-448f-b7c8-11f0e2bb947a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80e4ae3a-cadc-448f-b7c8-11f0e2bb947a")) {
#                     Plotly.newPlot(
#                         '80e4ae3a-cadc-448f-b7c8-11f0e2bb947a',
# ...

# %% [markdown]
# ###**EXERCISE 7**: *

# %% [markdown]
# Create the following map with provided dataset:

# %%
#DATA
gap_data = px.data.gapminder()

# %%
#CODE HERE

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bfd95e61-f082-4281-8359-904a03bebcec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bfd95e61-f082-4281-8359-904a03bebcec")) {
#                     Plotly.newPlot(
#                         'bfd95e61-f082-4281-8359-904a03bebcec',
# ...

# %% [markdown]
# # **KAHOOT**

# %%
#Imports
import plotly.express as px
import pandas as pd
from urllib.request import urlopen
import json

# %% [markdown]
# ###**KH 1**: *

# %% [markdown]
# How many crimes where reported in Cambridge area?
#
# A)0-50
#
# B)50-100
#
# C)100-500
#
# D)500-1000

# %%
#DATA
#District GeoJson
with urlopen('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/Police_Districts.geojson') as response:
    districts_geojson = json.load(response)

#Crime Data
crime_data = pd.read_csv('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/crime.csv', encoding='latin-1')
crime_data = crime_data[crime_data['DISTRICT'].notna()]

# %%
#CODE HERE

# %% [markdown]
# ###**KH 2**: *

# %% [markdown]
# How many districts share borders with district B2?
#
# A)2
#
# B)3
#
# C)4
#
# D)5

# %%
#DATA
#District GeoJson
with urlopen('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/Police_Districts.geojson') as response:
    districts_geojson = json.load(response)

#Crime Data
crime_data = pd.read_csv('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/crime.csv', encoding='latin-1')
crime_data = crime_data[crime_data['DISTRICT'].notna()]

# %%
#CODE HERE

# %% [markdown]
# ###**KH 3**: *

# %% [markdown]
# Which crime reported on the C6 district is the furthest away from the district area?
#
# A)I172010151
#
# B)I162022893
#
# C)I172019188
#
# D)I162005356

# %%
#DATA
#District GeoJson
with urlopen('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/Police_Districts.geojson') as response:
    districts_geojson = json.load(response)

#Crime Data
crime_data = pd.read_csv('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/crime.csv', encoding='latin-1')
crime_data = crime_data[crime_data['DISTRICT'].notna()]

# %% [markdown]
# ###**KH 4**: *

# %% [markdown]
# Which of the following crime code groups can be found in Long Island?
#
# A)Vandalism
#
# B)Towed
#
# C)Explosives
#
# D)Burglary

# %%
#DATA
#District GeoJson
with urlopen('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/Police_Districts.geojson') as response:
    districts_geojson = json.load(response)

#Crime Data
crime_data = pd.read_csv('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/crime.csv', encoding='latin-1')
crime_data = crime_data[crime_data['DISTRICT'].notna()]

# %%
#CODE HERE

# %% [markdown]
# ###**KH 5**: ***

# %% [markdown]
# Where are the districts with higher crime rates (larger amount of crimes reported)?
#
# A)Center
#
# B)North East
#
# C)South West

# %%
#DATA
#District GeoJson
with urlopen('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/Police_Districts.geojson') as response:
    districts_geojson = json.load(response)

#Crime Data
crime_data = pd.read_csv('https://raw.githubusercontent.com/AzIz000/machine-learning/master/datasets/crime.csv', encoding='latin-1')
crime_data = crime_data[crime_data['DISTRICT'].notna()]

# %%
#CODE HERE
